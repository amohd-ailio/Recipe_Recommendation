# %%
import numpy as np
import pandas as pd
import ast
# Import linear_kernel
import nltk
import string
import re
import unidecode
#nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from collections import Counter
import config 
from sklearn.metrics.pairwise import linear_kernel
#Import TfIdfVectorizer (scikit-learn)
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Loading data and looking at a  sample

# %%
df_82k = pd.read_csv ("C:/Users/Atif-Foxfire/Downloads/RAW_recipes.csv/recipes_82k.csv", sep="," )
#df_82k = pd.read_csv ("../data/salad-recipe-data/recipes_82k.csv", sep="," )

# %%
df_82k.head(10)
# Out:
#   category                                     cooking_method       cuisine  \
# 0      NaN  ['Set the racks in the middle and upper thirds...  ['American']
# 1      NaN  ['Place the eggs in the air fryer basket and c...  ['American']
# 2      NaN  ['Air Fryer directions:', 'Preheat air fryer t...  ['American']
# 3      NaN  ['Preheat the oven to 400F.', 'Pour 2 tablespo...  ['American']
# 4      NaN  ['Cook potatoes in a large pot of salted water...  ['American']
# 5      NaN  ['To Make the soup:', 'Heat 1 tablespoon of oi...  ['American']
# 6      NaN  ['Preheat the to 350F degrees. Spray a pie dis...  ['American']
# 7      NaN  ['Combine sour cream and brown sugar and mix w...  ['American']
# 8      NaN  ['Preheat the oven to 450F. Place a silicone l...  ['American']
# 9      NaN                                                 []           NaN
#
#                                                image  \
# 0  https://www.skinnytaste.com/wp-content/uploads...
# 1  https://www.skinnytaste.com/wp-content/uploads...
# 2  https://www.skinnytaste.com/wp-content/uploads...
# 3  https://www.skinnytaste.com/wp-content/uploads...
# 4  https://www.skinnytaste.com/wp-content/uploads...
# 5  https://www.skinnytaste.com/wp-content/uploads...
# 6  https://www.skinnytaste.com/wp-content/uploads...
# 7  https://www.skinnytaste.com/wp-content/uploads...
# 8  https://www.skinnytaste.com/wp-content/uploads...
# 9  https://www.skinnytaste.com/wp-content/uploads...
#
#                                          ingredients   prep_time  \
# 0  ['1 tablespoons extra virgin olive oil', '1 cu...  20 minutes
# 1  ['4 large eggs', 'Salt (black pepper, everythi...  15 minutes
# 2  ['olive oil spray', '4 about 5 ounce each salm...   5 minutes
# 3  ['1/2 cup freshly grated Parmesan (not pre-gra...  15 minutes
# 4  ['3 1/2 pounds new potatoes (about 10 peeled a...  10 minutes
# 5  ['2 tablespoons high-heat oil', '1 medium yell...   5 minutes
# 6  ['cooking spray', '1 3/4 cups diced ham steak ...  15 minutes
# 7  ['16 oz strawberries (washed and cut)', '4 oz ...   5 minutes
# 8  ['1 cup 5 oz all purpose or white whole wheat ...  15 minutes
# 9                                                 []   0 minutes
#
#                                      recipe_name       serves  \
# 0                         Mediterranean Sea Bass   4 servings
# 1                     Air Fryer Hard Boiled Eggs       4 eggs
# 2                Air Fryer Basil-Parmesan Salmon   4 servings
# 3                     Everything Parmesan Crisps   4 servings
# 4                    Potato and Green Bean Salad  12 servings
# 5   Green Detox Soup with Toasted Hemp Gremolata   2 servings
# 6                 Ham and Swiss Crustless Quiche   6 servings
# 7                          Strawberries Romanoff   5 Servings
# 8              Smoked Salmon Breakfast Flatbread   4 servings
# 9  Skinnytaste Air Fryer Cookbook: Get a Free 39            0
#
#                                                 tags
# 0  Dairy Free, Gluten Free, Keto Recipes, Kid Fri...
# 1  Air Fryer Recipes, Dairy Free, Gluten Free, Ke...
# 2  Air Fryer Recipes, Gluten Free, Keto Recipes, ...
# 3  Gluten Free, Keto Recipes, Kid Friendly, Low C...
# 4  Dairy Free, Gluten Free, Kid Friendly, Vegetar...
# 5  Dairy Free, Gluten Free, Under 30 Minutes, Veg...
# 6  Gluten Free, Keto Recipes, Kid Friendly, Low C...
# 7  Gluten Free, Kid Friendly, Low Carb, Under 30 ...
# 8   Air Fryer Recipes, Gluten Free, Under 30 Minutes
# 9                                  Air Fryer Recipes

# %%
df_82k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82245 entries, 0 to 82244
# Data columns (total 9 columns):
# category          18107 non-null object
# cooking_method    82245 non-null object
# cuisine           82230 non-null object
# image             82245 non-null object
# ingredients       82245 non-null object
# prep_time         58630 non-null object
# recipe_name       82245 non-null object
# serves            82244 non-null object
# tags              82011 non-null object
# dtypes: object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# ### Checking for duplicate recipe and ingrdients

# %%
print('No of Unique recipes: ',len(df_82k['recipe_name'].unique().tolist()))
print('No of Unique Ingredients: ', len(df_82k['ingredients'].unique().tolist()))
# Out:
# No of Unique recipes:  55838
# No of Unique Ingredients:  61198

# %% [markdown]
# ### Observations
# - Dataset consist of 82245 rows and 9 Columns
# - Text data no numerical data
# - preptime and serves can be converted into numerical data
# - a lot of duplicate recipes which can be removed
# - some or the rows have 'ingreidentS' value '[]' whch is null but can't be de

# %%
# Removing duplicate recipes
df_82k = df_82k.drop_duplicates(subset=['recipe_name'], keep='first')
df_82k = df_82k[df_82k.ingredients != "[]"]
df_82k.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Checking for Null / Missing  Values

# %%
type(df_82k['ingredients'])
total = df_82k.isnull().sum().sort_values(ascending=False)
percent = (df_82k.isnull().sum()/df_82k.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head()
# Out:
#            Total   Percent
# category   47498  0.863239
# prep_time  16466  0.299257
# tags         178  0.003235
# cuisine        8  0.000145
# serves         1  0.000018

# %% [markdown]
# ### Observations
# - A lot of values are missing from 'category' it can be removed

# %%
 # dropping category  column
df_82k.drop('category',1, inplace =True)

# %% [markdown]
# ## Data Cleaning
# ### Checking most frequently occuring words in 'ingredients'

# %%
vocabulary = nltk.FreqDist()
# This was done once I had already preprocessed the ingredients
for ingredients in df_82k['ingredients']:
    ingredients = ingredients.split()
    vocabulary.update(ingredients)
for word, frequency in vocabulary.most_common(200):
    print(f'{word};{frequency}')
# Out:
# '1;171451
# cup;118273
# '2;96269
# tablespoons;63076
# '1/2;60583
# teaspoon;59321
# and;59274
# cups;41954
# '1/4;40415
# ground;36763
# tablespoon;35952
# fresh;33730
# '3;29706
# for;29247
# pepper',;28915
# or;27776
# 1/2;27091
# '4;26186
# oil',;25672
# chopped;25267
# black;25021
# salt',;23817
# freshly;22855
# chopped',;21589
# ounces;20985
# olive;20020
# sugar',;19997
# large;19694
# teaspoons;19051
# to;18643
# into;17573
# red;17153
# cut;16481
# ['1;16029
# finely;15663
# plus;14806
# pound;13599
# 'Kosher;12852
# white;12147
# of;12062
# unsalted;11686
# 1;11534
# butter',;11003
# salt;10885
# small;10545
# 'Salt;10476
# sliced;10409
# garlic,;10405
# powder',;10372
# ['2;10343
# flour',;10293
# '6;10219
# '3/4;9917
# grated;9911
# sliced',;9788
# chicken;9502
# onion,;9387
# cloves;9308
# butter,;9226
# '8;9144
# juice',;8817
# pounds;8699
# (about;8693
# all-purpose;8651
# 2;8524
# vinegar',;8413
# thinly;8233
# cream',;8058
# medium;8034
# peeled;8014
# leaves',;7979
# vanilla;7962
# sauce',;7847
# recipe;7743
# dried;7330
# extra-virgin;7319
# '1/3;7224
# green;7203
# lemon;7079
# whole;7038
# kosher;7013
# water',;6979
# diced',;6887
# more;6879
# oil,;6815
# the;6789
# in;6726
# baking;6645
# minced',;6522
# milk',;6462
# follows',;6423
# as;6306
# minced;6289
# brown;6037
# extract',;5978
# 1/4;5894
# garlic;5867
# vegetable;5737
# can;5729
# pepper,;5464
# heavy;5412
# room;5368
# eggs',;5210
# pepper;5195
# diced;5154
# garlic',;5127
# slices;5072
# at;4833
# '12;4815
# '5;4778
# pepper'];4774
# 'Pinch;4774
# egg;4762
# cheese',;4706
# temperature',;4678
# pieces',;4653
# shredded;4440
# with;4351
# yellow;4313
# dry;4296
# bell;4262
# a;4258
# ['4;4247
# granulated;4202
# mustard',;4125
# 3;4110
# such;4083
# wine;4019
# tomatoes,;3942
# 'One;3864
# light;3850
# leaves,;3850
# cheese,;3843
# 'Freshly;3842
# frozen;3788
# orange;3779
# ['3;3713
# garnish',;3712
# wine',;3672
# 4;3636
# bunch;3591
# hot;3544
# coarsely;3463
# cinnamon',;3412
# seeded;3343
# honey',;3266
# stock',;3221
# packed;3201
# taste',;3199
# cream;3198
# lime;3187
# ['1/2;3148
# (recommended:;3148
# crushed;3106
# chocolate;3098
# sweet;3067
# 1/2-inch;3059
# roughly;3032
# (1;3002
# sour;2995
# parsley',;2963
# garnish'];2899
# peeled,;2869
# pure;2861
# sprigs;2853
# onion',;2851
# clove;2846
# cooked;2836
# onions,;2830
# leaves;2817
# thyme',;2789
# package;2781
# parsley;2751
# ginger',;2742
# bay;2737
# soy;2736
# chili;2730
# canola;2640
# paprika',;2624
# eggs,;2613
# flakes',;2582
# dark;2575
# seeds',;2573
# 1-inch;2552
# '1/8;2547
# cumin',;2546
# broth',;2538
# tomato;2485
# corn;2482
# Italian;2474
# soda',;2472
# mayonnaise',;2463
# toasted;2451
# tomatoes',;2442
# juiced',;2434
# lemon,;2427
# rice;2415
# Dijon;2407
# beef;2395
# cilantro;2394

# %% [markdown]
# ### Parsing 'ingredients' column and extractiting Vegetarian recipie and no of servings
# the ingredient need to pe parsed as it conatins a lot of commonly occurying words or ingredients such as quantities, measuring units like tabelspoon, cup , gram etc. or common form or state of ingredients used like, chopped, diced, cube, fresh etc. These words can induce a bias in predicting the similarilties between the recipe's ingredients and the input ingredients so parsing ingredients is the most crucial step in building a recipe reccomendation engine.

# %%
def ingredient_parser(ingreds):
    '''
    
    '''
    ingred_list = []
    measure_units = ['teaspoon', 't', 'tsp.', 'tsp','tablespoon', 'T', 'tbl.', 'tb', 'tbsp.', 'fluid ounce', 'fl oz', 'gill', 'cup', 'c', 'pint', 'p', 'pt', 'fl pt', 'quart', 'q', 'qt', 'fl qt', 'gallon', 'g', 'gal', 'ml', 'milliliter', 'millilitre', 'cc', 'mL', 'l', 'liter', 'litre', 'L', 'dl', 'deciliter', 'decilitre', 'dL', 'bulb', 'level', 'heaped', 'rounded', 'whole', 'pinch', 'medium', 'slice', 'pound', 'lb', '#', 'ounce', 'oz', 'mg', 'milligram', 'milligramme', 'g', 'gram', 'gramme', 'kg', 'kilogram', 'kilogramme', 'x', 'of', 'mm', 'millimetre', 'millimeter', 'cm', 'centimeter', 'centimetre', 'm', 'meter', 'metre', 'inch', 'in', 'milli', 'centi', 'deci', 'hecto', 'kilo']
    words_to_remove = ['spicy','allspice','sweetened','bittersweet','golden','flavored','use','coloring','intant','sifted','ice','pure','at','follows','like','sir','granulated','powdered','topping','squeezed','pan','dice','cracked','nonstick','bag','semisweet','plum','whipped','smashed','very','zested','drizzling','well','sharp','reserved','bought','box','cored','salad','reduced','mini','by','julienned','everything','about','each','chopped','diced','together','fresh', 'oil', 'a', 'red', 'bunch', 'and', 'clove', 'or', 'leaf', 'chilli', 'large', 'extra', 'sprig',
    'ground', 'handful', 'free', 'small','brushing','de','slated','recipe','serving','minced', 'pepper', 'virgin', 'range', 'from', 'dried', 'sustainable', 'black', 'peeled', 'higher',
                       'welfare', 'seed', 'for', 'finely', 'freshly', 'sea', 'quality', 'white', 'ripe', 'few', 'piece', 'source', 'to',
                       'organic', 'flat', 'smoked', 'ginger', 'sliced', 'green', 'picked', 'the', 'stick', 'plain', 'plus', 'mixed', 'mint',
                       'bay', 'basil', 'your', 'cumin', 'optional', 'fennel', 'serve', 'mustard', 'unsalted', 'baby', 'paprika', 'fat', 'ask',
                       'natural', 'skin', 'roughly', 'into', 'such', 'cut', 'good', 'brown', 'grated', 'trimmed', 'oregano', 'powder', 'yellow',
                       'dusting', 'knob', 'frozen', 'on', 'deseeded', 'low', 'runny', 'balsamic', 'cooked', 'streaky', 'nutmeg', 'sage', 'rasher',
                       'zest', 'pin', 'groundnut', 'breadcrumb','long-grain', 'turmeric', 'halved', 'grating', 'stalk', 'light', 'tinned', 'dry', 'soft', 'rocket',
                       'bone', 'colour', 'washed', 'skinless', 'leftover', 'splash', 'removed', 'dijon', 'thick', 'big', 'hot', 'drained', 'sized',
                       'chestnut', 'watercress', 'fishmonger', 'english', 'dill', 'caper', 'raw', 'worcestershire', 'flake', 'cider', 'cayenne',
                       'tbsp', 'leg', 'pine', 'wild', 'if', 'fine', 'herb', 'almond', 'shoulder', 'cube', 'dressing', 'with', 'chunk', 'spice', 'thumb',
                       'garam', 'new', 'little', 'punnet', 'peppercorn', 'shelled', 'saffron', 'other','chopped', 'salt', 'olive', 'taste', 'can', 'sauce',
                       'water', 'diced', 'package', 'italian', 'shredded', 'divided', 'parsley', 'vinegar', 'all', 'purpose', 'crushed', 'juice', 'more',
                       'coriander', 'bell', 'needed', 'thinly', 'boneless', 'half', 'thyme', 'cubed', 'cinnamon', 'cilantro', 'jar', 'seasoning', 'rosemary',
                       'extract', 'sweet', 'baking', 'beaten', 'heavy', 'seeded', 'tin', 'vanilla', 'uncooked', 'crumb', 'style', 'thin', 'nut', 'coarsely',
                       'spring', 'chili', 'cornstarch', 'strip', 'cardamom', 'rinsed', 'honey', 'cherry', 'root', 'quartered', 'head', 'softened', 'container',
                       'crumbled', 'frying', 'lean', 'cooking', 'roasted', 'warm', 'whipping', 'thawed', 'corn', 'pitted', 'sun', 'kosher', 'bite', 'toasted', 'lasagna',
                       'split', 'melted', 'degree', 'lengthwise', 'romano', 'packed', 'pod', 'anchovy', 'rom', 'prepared', 'juiced', 'fluid', 'floret', 'room', 'active',
                       'seasoned', 'mix', 'deveined', 'lightly', 'anise', 'thai', 'size', 'unsweetened', 'torn', 'wedge', 'sour', 'basmati', 'marinara', 'dark',
                       'temperature', 'garnish', 'bouillon', 'loaf', 'shell', 'reggiano', 'canola', 'parmigiano', 'round', 'canned', 'ghee', 'crust', 'long',
                       'broken', 'ketchup', 'bulk', 'cleaned', 'condensed', 'sherry', 'provolone', 'cold', 'soda', 'cottage', 'spray', 'tamarind', 'pecorino',
                       'shortening', 'part', 'bottle', 'sodium', 'cocoa', 'grain', 'french', 'roast', 'stem', 'link', 'firm', 'asafoetida', 'mild', 'dash', 'boiling','one','two','three','four']
    
    #Check input ingredient is a list or not if not then convert it into a list. We use ast.literal_eval
    if isinstance(ingreds, list):
        ingredients = ingreds
    else:
        try:
            ingredients = ast.literal_eval(ingreds)
        except:
            return  'none'

    # We first get rid of all the punctuation. We make use of str.maketrans. It takes three input 
    # arguments 'x', 'y', 'z'. 'x' and 'y' must be equal-length strings and characters in 'x'
    # are replaced by characters in 'y'. 'z' is a string (string.punctuation here) where each character
    #  in the string is mapped to None. 
    translator = str.maketrans('', '', string.punctuation)
    lemmatizer = WordNetLemmatizer()
    try:
        for i in ingredients:
            i.translate(translator)
            # We split up with hyphens as well as spaces
            items = re.split(' |-|,', i)
            # Get rid of words containing non alphabet letters
            items = [word for word in items if word.isalpha()]
            # Turn everything to lowercase
            items = [word.lower() for word in items]
            # remove accents
            items = [unidecode.unidecode(word) for word in items] 
            # Lemmatize words so we can compare words to measuring words
            items = [lemmatizer.lemmatize(word) for word in items]
            # Gets rid of measuring units/words
            items = [word for word in items if word not in measure_units]
            # Get rid of commonly occuring words
            items = [word for word in items if word not in words_to_remove]
            if items:
                ingred_list.append(' '.join(items)) 
        ingred_list = " ".join(ingred_list)
    except:
            return ingred_list
    return ingred_list

def vegeterian_parser(ingreds):
    '''
    
    '''
    ingred_list =[]
    non_veg = ['chicken','duck','turkey','buffalo','egg', 'eggs', 'beef','ham','bacon','salami','sausage','pepperoni','steak', 'pork','lamb', 'fish', 'shrimp', 'meat', 'flesh','sardine','tuna','salmon','tilapia','cod',
              'snapper','herring','anchovies','haddock','flounder','trout','catfish','pollock','bass','halibut','sowrdfish','pike',
              'mackerel']
    
    
    #Check input ingredient is a list or not if not then convert it into a list. We use ast.literal_eval
    if isinstance(ingreds, list):
        ingredients = ingreds
    else:
        try:
            ingredients = ast.literal_eval(ingreds)
        except:
            return 'none'

    
    translator = str.maketrans('', '', string.punctuation)
    veg = "yes"
    for i in ingredients:
        i.translate(translator)
        # We split up with hyphens as well as spaces
        items = re.split(' |-|,', i)
        # Get rid of words containing non alphabet letters
        items = [word for word in items if word.isalpha()]
        # Turn everything to lowercase
        items = [word.lower() for word in items]
        # remove accents
        items = [unidecode.unidecode(word) for word in items] 
                
        if items:
            ingred_list.append(' '.join(items)) 
    ingred_list = " ".join(ingred_list)
    ingred_list=  list(ingred_list.split(" "))
    if any(x in non_veg for x in ingred_list):
        veg = "no"
    ''''for word in ingred_list:
        print (word)
        if word  in non_veg:
            veg = "no"'''
    return veg

def serving_extractor(servings):
    translator = str.maketrans('', '', string.punctuation)
    try:
        servings = str(servings)
        servings = re.split(" |-", servings)
        no_of_servings = 0
        for i in range (len(servings)):
            servings[i] = servings[i].translate(translator)
            if servings[i].isdigit():
                no_of_servings = servings[i]
                break
    except:
        return 0
    return no_of_servings

# %%
#Creating a new column of parsed ingredients vegetarian and no_of_servings
df_82k['parsed_ingredients'] = df_82k['ingredients'].apply(lambda x: ingredient_parser(x))

df_82k['vegetarian'] = df_82k['ingredients'].apply(lambda x: vegeterian_parser(x))

df_82k['no_of_servings'] = df_82k['serves'].apply(lambda x: serving_extractor(x))

#df_82k['parsed_cusine'] = df_82k['cuisine'].apply(lambda x: ingredient_parser(x))

# %%
# Dropping Cuisine Preptime and serves columns
df_82k.drop(['cuisine','prep_time','serves'],1, inplace =True)

# %% [markdown]
# ### Looking at new 'parsed_ingredients'

# %%
df_82k.sample(10)
# Out:
#                                           cooking_method  \
# 49144  ['Heat extra-virgin olive oil in a soup pot ov...
# 41205  ['Put flour and sesame seeds on separate sheet...
# 47017  ['Sprinkle 1 tablespoon of the gelatin over th...
# 24464  ['Preheat oven to 375 degrees F. Grease a 9 by...
# 32357  ['Cook the pasta in boiling salted water until...
# 39293  ['Directions', 'Preheat oven to 220 degrees. W...
# 29077  ['Preheat the oven to 200 degrees F.', 'Spray ...
# 35234  ['Preheat the oven to 350 degrees F. Grease a ...
# 20376  ['Preheat oven to 450 degrees F.', 'Slice port...
# 35876  ['Heat 1 tablespoon of olive oil in casserole ...
#
#                                                    image  \
# 49144  https://food.fnr.sndimg.com/content/dam/images...
# 41205  https://food.fnr.sndimg.com/content/dam/images...
# 47017  https://food.fnr.sndimg.com/content/dam/images...
# 24464  https://food.fnr.sndimg.com/content/dam/images...
# 32357  https://food.fnr.sndimg.com/content/dam/images...
# 39293  https://food.fnr.sndimg.com/content/dam/images...
# 29077  https://food.fnr.sndimg.com/content/dam/images...
# 35234  https://food.fnr.sndimg.com/content/dam/images...
# 20376  https://food.fnr.sndimg.com/content/dam/images...
# 35876  https://food.fnr.sndimg.com/content/dam/images...
#
#                                              ingredients  \
# 49144  ['2 tablespoons extra-virgin olive oil', '1 ca...
# 41205  ['1 1/2 tablespoons all purpose flour', '2 tab...
# 47017  ['3 tablespoons powdered gelatin', '1 1/4 cups...
# 24464  ['4 tablespoons butter, plus 1 tablespoon for ...
# 32357  ['1 (16-ounce) package whole-wheat linguine', ...
# 39293  ['12 to 15 pound ham, spiral cut preferably', ...
# 29077  ['Eight 6-inch whole wheat tortillas', 'Cookin...
# 35234  ['1 tablespoon unsalted butter, at room temper...
# 20376  ['3 portobello mushroom caps', '2 tablespoons ...
# 35876  ['4 tablespoons olive oil', '3 whole chickens ...
#
#                                              recipe_name  \
# 49144                         Three Bean Pasta e Fagioli
# 41205  Sesame Chicken with Napa Cabbage and Spinach S...
# 47017                      Striped Jiggly Fruit Shooters
# 24464                              Glazed Sweet Potatoes
# 32357                                     Pasta Stir-Fry
# 39293                 Rootbeer Ham with Kumquats Recipe
# 29077                   Ham, Apple and Cheese Quesadilla
# 35234                  Prune Plum and Walnut Butter Cake
# 20376                    For the Love of Mushrooms Pizza
# 35876                                     Potted Chicken
#
#                                                     tags  \
# 49144  Easy Pasta Recipes,Easy,Pasta Recipes,Easy Mai...
# 41205  Skillet Recipes,American,Asian,Sandwich,Chicke...
# 47017  Fruit Dessert Recipes,Dessert,Fruit,American,T...
# 24464  Easy Side Dish Recipes,Easy,Side Dish,Easy Din...
# 32357  Budget-Friendly,Wok Recipes,Asian,Pasta Recipe...
# 39293  Ham,Meat,Fruit,Grape Recipes,Main Dish,Gluten ...
# 29077  Healthy Dinner,Healthy,Quesadilla,Apple,Fruit,...
# 35234  Fruit Dessert Recipes,Dessert,Fruit,Baking,Ame...
# 20376  Italian Pizza,Italian,Pizza Restaurants,Vegeta...
# 35876  Chicken Casserole,Casserole,Chicken,Poultry,Eu...
#
#                                       parsed_ingredients vegetarian  \
# 49144  carrot rib celery heart onion garlic cannellin...         no
# 41205  flour sesame egg chicken breast flattened slig...         no
# 47017  gelatin strawberry banana another pink fruit c...        yes
# 24464       butter greasing yam potato sugar maple syrup        yes
# 32357  wheat linguine onion eggplant garlic broccoli ...         no
# 39293  ham spiral preferably rootbeer sugar kumquat s...         no
# 29077  eight wheat tortilla oiling tortilla swiss for...         no
# 35234  butter unbleached flour prune sugar brandy lem...         no
# 20376  portobello mushroom cap butter pizza dough pre...        yes
# 35876  chicken down onion garlic tomato orange chicke...         no
#
#       no_of_servings
# 49144              4
# 41205              4
# 47017              8
# 24464              4
# 32357              4
# 39293              0
# 29077              4
# 35234              8
# 20376              2
# 35876              6

# %% [markdown]
# ### Checking most frequently occuring words in 'parsed_ingredients'
# (These observation are iterated over many steps to further enhanced the list of words to remove as most commonly occuring words will induce a bias in model's calculatin )

# %%
vocabulary = nltk.FreqDist()
# This was done once I had already preprocessed the ingredients
for ingredients in df_82k['parsed_ingredients']:
    ingredients = ingredients.split()
    vocabulary.update(ingredients)
for word, frequency in vocabulary.most_common(200):
    print(f'{word};{frequency}')
# Out:
# sugar;26367
# butter;23202
# garlic;22097
# onion;19182
# egg;16605
# cream;14510
# flour;14407
# lemon;13350
# cheese;11887
# tomato;11791
# chicken;11281
# milk;8749
# wine;8407
# vegetable;8027
# lime;6705
# chocolate;6643
# orange;6262
# potato;5591
# bread;4936
# rice;4832
# stock;4641
# chile;4618
# bean;4564
# carrot;4433
# apple;4075
# parmesan;4016
# celery;4013
# scallion;3838
# shallot;3737
# beef;3649
# mushroom;3372
# broth;3346
# pork;2957
# mayonnaise;2940
# bacon;2928
# soy;2921
# syrup;2882
# peanut;2834
# jalapeno;2722
# breast;2618
# paste;2582
# chive;2581
# chip;2575
# coconut;2564
# sesame;2481
# cheddar;2396
# yolk;2309
# shrimp;2250
# fillet;2082
# steak;2043
# lettuce;1922
# strawberry;1901
# spinach;1889
# tortilla;1786
# buttermilk;1778
# yogurt;1724
# mozzarella;1716
# rib;1715
# turkey;1682
# sausage;1639
# cucumber;1618
# pea;1599
# cake;1571
# avocado;1570
# pineapple;1563
# coarse;1560
# raspberry;1526
# pecan;1497
# walnut;1470
# wheat;1425
# cranberry;1387
# chipotle;1357
# stemmed;1357
# banana;1348
# cabbage;1330
# fish;1323
# pasta;1314
# grape;1310
# dough;1288
# food;1236
# zucchini;1214
# chilled;1198
# maple;1187
# roll;1171
# liqueur;1171
# store;1144
# squash;1141
# rum;1138
# salted;1138
# ham;1134
# blue;1123
# pumpkin;1109
# jack;1099
# raisin;1093
# arugula;1087
# salmon;1085
# peach;1040
# pie;1039
# sheet;1033
# preferably;1011
# spanish;1007
# meat;994
# ricotta;981
# tarragon;977
# cornmeal;974
# mango;950
# puree;948
# cracker;944
# separated;920
# beer;905
# only;892
# candy;887
# blueberry;881
# broccoli;873
# salsa;870
# pear;862
# greasing;852
# goat;845
# yeast;844
# vodka;843
# greek;827
# sprinkling;827
# noodle;817
# panko;816
# top;814
# coffee;806
# adobo;803
# asparagus;802
# fruit;802
# bun;801
# homemade;789
# leek;789
# kernel;789
# pastry;789
# pickled;789
# old;776
# thigh;774
# creme;774
# russet;773
# romaine;773
# ear;766
# gold;756
# mexican;754
# heart;749
# pizza;746
# blanched;741
# pickle;726
# curry;722
# apricot;715
# serrano;710
# hazelnut;702
# ancho;699
# horseradish;693
# instant;691
# berry;685
# feta;684
# chop;682
# molasses;681
# tenderloin;678
# seedless;677
# grilled;671
# baguette;671
# crosswise;671
# swiss;669
# oyster;662
# soaked;657
# granny;657
# clam;656
# shiitake;653
# smith;652
# mashed;644
# veal;640
# yukon;632
# oat;630
# brandy;623
# eggplant;620
# blend;619
# grapeseed;616
# percent;616
# bourbon;611
# crab;609
# prosciutto;608
# marshmallow;607
# lamb;602
# sprout;601
# tail;594
# monterey;594
# boiled;592
# cooky;592
# it;591
# fried;590
# artichoke;584
# spaghetti;582
# grill;581
# liquid;578
# cooled;565
# scrubbed;562
# end;560
# radish;560
# tuna;558

# %% [markdown]
# ### Add specific index column

# %%
df_82k['id'] = df_82k.index.values
df_82k.head(5)
# Out:
#                                       cooking_method  \
# 0  ['Set the racks in the middle and upper thirds...
# 1  ['Place the eggs in the air fryer basket and c...
# 2  ['Air Fryer directions:', 'Preheat air fryer t...
# 3  ['Preheat the oven to 400F.', 'Pour 2 tablespo...
# 4  ['Cook potatoes in a large pot of salted water...
#
#                                                image  \
# 0  https://www.skinnytaste.com/wp-content/uploads...
# 1  https://www.skinnytaste.com/wp-content/uploads...
# 2  https://www.skinnytaste.com/wp-content/uploads...
# 3  https://www.skinnytaste.com/wp-content/uploads...
# 4  https://www.skinnytaste.com/wp-content/uploads...
#
#                                          ingredients  \
# 0  ['1 tablespoons extra virgin olive oil', '1 cu...
# 1  ['4 large eggs', 'Salt (black pepper, everythi...
# 2  ['olive oil spray', '4 about 5 ounce each salm...
# 3  ['1/2 cup freshly grated Parmesan (not pre-gra...
# 4  ['3 1/2 pounds new potatoes (about 10 peeled a...
#
#                        recipe_name  \
# 0           Mediterranean Sea Bass
# 1       Air Fryer Hard Boiled Eggs
# 2  Air Fryer Basil-Parmesan Salmon
# 3       Everything Parmesan Crisps
# 4      Potato and Green Bean Salad
#
#                                                 tags  \
# 0  Dairy Free, Gluten Free, Keto Recipes, Kid Fri...
# 1  Air Fryer Recipes, Dairy Free, Gluten Free, Ke...
# 2  Air Fryer Recipes, Gluten Free, Keto Recipes, ...
# 3  Gluten Free, Keto Recipes, Kid Friendly, Low C...
# 4  Dairy Free, Gluten Free, Kid Friendly, Vegetar...
#
#                                   parsed_ingredients vegetarian  \
# 0  onion garlic tomato their wine kalamata chilea...         no
# 1                                          egg bagel         no
# 2     salmon fillet lemon mayonnaise parmesan cheese         no
# 3  parmesan pre using hole sesame onion garlic poppy        yes
# 4                          potato bean bean scallion        yes
#
#   no_of_servings  id
# 0              4   0
# 1              4   1
# 2              4   2
# 3              4   3
# 4             12   4

# %% [markdown]
# ### Add number of ingredients as specific columns

# %%
def count_n_ingredients(ingreds):
    ingreds_list = ingreds.split()
    n_ingredients = len(ingreds_list)
    return n_ingredients

# %%
df_82k['n_ingredients'] = [count_n_ingredients(x) for x in df_82k['parsed_ingredients']]
df_82k.head(5)
# Out:
#                                       cooking_method  \
# 0  ['Set the racks in the middle and upper thirds...
# 1  ['Place the eggs in the air fryer basket and c...
# 2  ['Air Fryer directions:', 'Preheat air fryer t...
# 3  ['Preheat the oven to 400F.', 'Pour 2 tablespo...
# 4  ['Cook potatoes in a large pot of salted water...
#
#                                                image  \
# 0  https://www.skinnytaste.com/wp-content/uploads...
# 1  https://www.skinnytaste.com/wp-content/uploads...
# 2  https://www.skinnytaste.com/wp-content/uploads...
# 3  https://www.skinnytaste.com/wp-content/uploads...
# 4  https://www.skinnytaste.com/wp-content/uploads...
#
#                                          ingredients  \
# 0  ['1 tablespoons extra virgin olive oil', '1 cu...
# 1  ['4 large eggs', 'Salt (black pepper, everythi...
# 2  ['olive oil spray', '4 about 5 ounce each salm...
# 3  ['1/2 cup freshly grated Parmesan (not pre-gra...
# 4  ['3 1/2 pounds new potatoes (about 10 peeled a...
#
#                        recipe_name  \
# 0           Mediterranean Sea Bass
# 1       Air Fryer Hard Boiled Eggs
# 2  Air Fryer Basil-Parmesan Salmon
# 3       Everything Parmesan Crisps
# 4      Potato and Green Bean Salad
#
#                                                 tags  \
# 0  Dairy Free, Gluten Free, Keto Recipes, Kid Fri...
# 1  Air Fryer Recipes, Dairy Free, Gluten Free, Ke...
# 2  Air Fryer Recipes, Gluten Free, Keto Recipes, ...
# 3  Gluten Free, Keto Recipes, Kid Friendly, Low C...
# 4  Dairy Free, Gluten Free, Kid Friendly, Vegetar...
#
#                                   parsed_ingredients vegetarian  \
# 0  onion garlic tomato their wine kalamata chilea...         no
# 1                                          egg bagel         no
# 2     salmon fillet lemon mayonnaise parmesan cheese         no
# 3  parmesan pre using hole sesame onion garlic poppy        yes
# 4                          potato bean bean scallion        yes
#
#   no_of_servings  id  n_ingredients
# 0              4   0             15
# 1              4   1              2
# 2              4   2              6
# 3              4   3              8
# 4             12   4              4

# %% [markdown]
# ### Saving the Dataset into CSV file

# %%
df_82k.to_csv("../data/parsed_recipes.csv", sep=",", index_label = id)

# %% [markdown]
# ### Save to .pkl

# %%
df_82k.to_pickle("../data/parsed_recipes.pkl")

# %% [markdown]
# ### Load dataframe

# %%
df = pd.read_pickle("../data/parsed_recipes.pkl")
df.head(3)
# Out:
#                                       cooking_method  \
# 0  ['Set the racks in the middle and upper thirds...
# 1  ['Place the eggs in the air fryer basket and c...
# 2  ['Air Fryer directions:', 'Preheat air fryer t...
#
#                                                image  \
# 0  https://www.skinnytaste.com/wp-content/uploads...
# 1  https://www.skinnytaste.com/wp-content/uploads...
# 2  https://www.skinnytaste.com/wp-content/uploads...
#
#                                          ingredients  \
# 0  ['1 tablespoons extra virgin olive oil', '1 cu...
# 1  ['4 large eggs', 'Salt (black pepper, everythi...
# 2  ['olive oil spray', '4 about 5 ounce each salm...
#
#                        recipe_name  \
# 0           Mediterranean Sea Bass
# 1       Air Fryer Hard Boiled Eggs
# 2  Air Fryer Basil-Parmesan Salmon
#
#                                                 tags  \
# 0  Dairy Free, Gluten Free, Keto Recipes, Kid Fri...
# 1  Air Fryer Recipes, Dairy Free, Gluten Free, Ke...
# 2  Air Fryer Recipes, Gluten Free, Keto Recipes, ...
#
#                                   parsed_ingredients vegetarian  \
# 0  onion garlic tomato their wine kalamata chilea...         no
# 1                                          egg bagel         no
# 2     salmon fillet lemon mayonnaise parmesan cheese         no
#
#   no_of_servings  id  n_ingredients
# 0              4   0             15
# 1              4   1              2
# 2              4   2              6

# %% [markdown]
# ## Add dataframe to postgresql database

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres:MySQLPW@localhost:5432/WhatToCook')

# %%
df.to_sql('recipes', engine)

# %% [markdown]
# ## Building Model
# ### TfidfVectorizer and Cosine Similarity

# %% [markdown]
# ### TF-IDF Vectorizer
# TF-IDF is short for term frequency–inverse document frequency, is a numerical statistic that is intended to reflect how important a word is to a document in a collection or corpus.  The tf–idf value increases proportionally to the number of times a word appears in the document and is offset by the number of documents in the corpus that contain the word, which helps to adjust for the fact that some words appear more frequently in general.
#
# ### Cosine Similarity
# cosine similarity is a measure of similarity between two sequences of numbers. For defining it, the sequences are viewed as vectors in an inner product space, and the cosine similarity is defined as the cosine of the angle between them, that is, the dot product of the vectors divided by the product of their lengths. It follows that the cosine similarity does not depend on the magnitudes of the vectors, but only on their angle. Cosine similarity can give a useful measure of how similar two documents are likely to be, in terms of their subject matter, and indepently of the length of the documents.

# %%
# TF-IDF feature extractor
tfidf = TfidfVectorizer(stop_words='english')
tfidf.fit(df_82k['parsed_ingredients'])
tfidf_recipe = tfidf.transform(df_82k['parsed_ingredients'])

# %%
tfidf_recipe.shape
# Out:
# (55023, 8928)

# %% [markdown]
# ### Example ingredients

# %%
input_ingredients = ['Tomato', 'onion', 'potato', 'beef', "rice"]

# %% [markdown]
# ### Claculating Similarity

# %%
# parse the ingredients using my ingredient_parser
try:
    ingredients_parsed = ingredient_parser(input_ingredients)
except:
    ingredients_parsed = ingredient_parser([input_ingredients])
    
# use pretrained  model to encode our input ingredients
input_ingredients_tfidf = tfidf.transform([ingredients_parsed])

# calculate cosine similarity between actual recipe ingreds and input ingreds
cos_sim = map(lambda x: cosine_similarity(input_ingredients_tfidf, x), tfidf_recipe)
scores = list(cos_sim)

# %%
print(scores[0])
# Out:
# [[0.07889054]]

# %% [markdown]
# ### Getting  top 5 recomendations

# %%
# getting top 5 recomendations
top_score = sorted(range(len(scores)), key=lambda i: scores[i], reverse=True)[:5]
recommendation_df = pd.DataFrame(columns = ['recipe_name', 'ingredients','cooking_method','cuisine', 'score' ])

count = 0
for i in top_score:
    recommendation_df.at[count, 'recipe_name'] = (df_82k['recipe_name'][i])
    recommendation_df.at[count, 'ingredients'] = (df_82k['ingredients'][i])
    recommendation_df.at[count, 'cooking_method'] = df_82k['cooking_method'][i]
    recommendation_df.at[count, 'no_of_servings'] = df_82k['no_of_servings'][i]
    recommendation_df.at[count, 'score'] = "{:.3f}".format(float(scores[i]))
    count += 1

# %% [markdown]
# ### Reccomendations

# %%
recommendation_df.head()
# Out:
#                         recipe_name  \
# 0                   Porcupine Balls
# 1  Cuban Beef Stew: Carne con Papas
# 2                   Dressed Up Rice
# 3                   Portuguese Rice
# 4   Hopkins County Stew Family Size
#
#                                          ingredients  \
# 0  ['1 pound lean ground beef', '1 1/2 cups uncoo...
# 1  ['1/4 cup olive oil', '1 large white onion, cu...
# 2  ['1 cup brown rice', '1 cup beef stock', '1 1/...
# 3  ['1/4 cup olive oil', '1 1/2 cups finely chopp...
# 4  ['4 cups water', '2 pounds skinless chicken or...
#
#                                       cooking_method cuisine  score  \
# 0  ['Preheat the oven to 350 degrees F.', 'Put th...     NaN  0.768
# 1  ['In a heavy skillet, heat oil and saute onion...     NaN  0.712
# 2  ['In a rice cooker, mix the rice, stock, water...     NaN  0.648
# 3  ['In a 4-quart medium saucepan heat the oil ov...     NaN  0.645
# 4  ['Heat 4 cups water to boiling in a 5-quart sa...     NaN  0.634
#
#   no_of_servings
# 0              4
# 1              6
# 2              4
# 3              6
# 4              6

# %% [markdown]
# ## Second Model Using Fuzz

# %%
from thefuzz import fuzz
from thefuzz import process

# %%
fuzz_ratio =  map(lambda x: fuzz.ratio(ingredients_parsed, x), df_82k['parsed_ingredients'])
#df_82k['ingredients'].apply(lambda x: fuzz.ratio(x))
fuzz_score = list(fuzz_ratio)

# %%
# getting top 5 recomendations
fuzz_score_top = sorted(range(len(fuzz_score)), key=lambda i: fuzz_score[i], reverse=True)[:5]
recommendation_dfuzz = pd.DataFrame(columns = ['recipe_name', 'ingredients','cooking_method','cuisine', 'score' ])

count = 0
for i in fuzz_score_top:
    recommendation_dfuzz.at[count, 'recipe_name'] = (df_82k['recipe_name'][i])
    recommendation_dfuzz.at[count, 'ingredients'] = (df_82k['ingredients'][i])
    recommendation_dfuzz.at[count, 'cooking_method'] = df_82k['cooking_method'][i]
    recommendation_dfuzz.at[count, 'no_of_servings'] = df_82k['no_of_servings'][i]
    recommendation_dfuzz.at[count, 'score'] = "{:.3f}".format(float(fuzz_score[i]))
    count += 1

# %%
recommendation_dfuzz.head()
# Out:
#                                          recipe_name  \
# 0  Pommes De Terre a la Boulangere: Potatoes a la...
# 1                                 Basic Tomato Sauce
# 2         Roasted Sweet Potato and Green Onion Salad
# 3                             Tomato-Red Onion Salad
# 4                           Sunny's Spicy Tomato Dip
#
#                                          ingredients  \
# 0  ['3 tablespoons butter', '1 tablespoon olive o...
# 1  ['Two 28-ounce cans whole peeled tomatoes', '1...
# 2  ['4 medium sweet potatoes (about 1 pound each)...
# 3  ['3 tablespoons balsamic vinegar', '1 teaspoon...
# 4  ['2 tablespoons olive oil', '2 pints cherry to...
#
#                                       cooking_method cuisine   score  \
# 0  ['Preheat the oven to 300 degrees F.', 'Melt h...     NaN  75.000
# 1  ['Add the tomatoes to a blender and puree unti...     NaN  71.000
# 2  ['Brush the potatoes and green onions with oli...     NaN  70.000
# 3  ['Whisk together the vinegar and mustard in a ...     NaN  70.000
# 4  ['Heat the oil in a medium pot or pan over med...     NaN  69.000
#
#   no_of_servings
# 0              6
# 1              6
# 2              8
# 3              4
# 4              1

# %% [markdown]
# ### Observation
# In comparison between the twomodels, using 'TfidfVectorizer' and cosine similarity the model score is much better than the 'fuzz' model so we have decided to use it for our reccomendations.
